# %%
! pip install transformers
! pip install optuna
! pip install gdown

from google.colab import drive
drive.mount('/content/drive')

! gdown "1UjEYJOauAanJ0UzuSRrCVLn6GHvJyWus&confirm=t"
! gdown --id 16YwJWsljY2r2R4Fzh4xLilSbPjowlZr_
! gdown --id 1YDr6ejvJPiQL3HAWR7i71GanzWsfxlQo
! gdown --id 11hYRWLmxyWd3j-rQsKTPS1fCuQvSFWcl
! gdown --id 1z2FvuIDZPUTKXJ0_Z6VBvFEzRteTLIa5
! gdown --id 1hEX89Ffv_lu8uIoOuX5trX0RqYFiI0Of
! gdown --id 1MD4pEghAgkpkxhr9Tyx_cEqGggki_XBu
! gdown --id 1py1b9IQhqwAM_It8iFleuksNBMR6uLs3 -O dev_A.csv
! gdown --id 1swL_8D5XehIBKRg59M3IcR4vZu7qBF7c
# ! gdown --id 13cxOgY3K17ubMFC7MKYqN7ncYWCDg4YZ

! yes A | unzip train_data.zip
! yes A | unzip eval_A.zip

# %%
! python Task_10_A.py
# Out:
# 2023-01-19 09:49:02.925608: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading: 100% 482/482 [00:00<00:00, 797kB/s]
# Downloading: 100% 899k/899k [00:00<00:00, 5.17MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 3.38MB/s]
# Downloading: 100% 1.36M/1.36M [00:00<00:00, 7.42MB/s]
# Downloading: 100% 1.43G/1.43G [00:18<00:00, 77.9MB/s]
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Checkpoit is False
# model loaded
# EPOCH [1/10] | STEP [100/1400] | CE Loss 0.6894
# EPOCH [1/10] | STEP [100/1400] | ADV Loss 0.7582
# EPOCH [1/10] | STEP [100/1400] | CON Loss 0.2475
# EPOCH [1/10] | STEP [100/1400] | VAT Loss 0.0028
# EPOCH [1/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [200/1400] | CE Loss 0.6864
# EPOCH [1/10] | STEP [200/1400] | ADV Loss 0.7129
# EPOCH [1/10] | STEP [200/1400] | CON Loss 0.2848
# EPOCH [1/10] | STEP [200/1400] | VAT Loss 0.0051
# EPOCH [1/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [300/1400] | CE Loss 0.6785
# EPOCH [1/10] | STEP [300/1400] | ADV Loss 0.7098
# EPOCH [1/10] | STEP [300/1400] | CON Loss 0.2397
# EPOCH [1/10] | STEP [300/1400] | VAT Loss 0.0026
# EPOCH [1/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [400/1400] | CE Loss 0.6656
# EPOCH [1/10] | STEP [400/1400] | ADV Loss 0.7054
# EPOCH [1/10] | STEP [400/1400] | CON Loss 0.2315
# EPOCH [1/10] | STEP [400/1400] | VAT Loss 0.0025
# EPOCH [1/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [500/1400] | CE Loss 0.6314
# EPOCH [1/10] | STEP [500/1400] | ADV Loss 0.6988
# EPOCH [1/10] | STEP [500/1400] | CON Loss 0.229
# EPOCH [1/10] | STEP [500/1400] | VAT Loss 0.0079
# EPOCH [1/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [600/1400] | CE Loss 0.5617
# EPOCH [1/10] | STEP [600/1400] | ADV Loss 0.6561
# EPOCH [1/10] | STEP [600/1400] | CON Loss 0.2075
# EPOCH [1/10] | STEP [600/1400] | VAT Loss 0.0228
# EPOCH [1/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [700/1400] | CE Loss 0.5315
# EPOCH [1/10] | STEP [700/1400] | ADV Loss 0.6355
# EPOCH [1/10] | STEP [700/1400] | CON Loss 0.1912
# EPOCH [1/10] | STEP [700/1400] | VAT Loss 0.0251
# EPOCH [1/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [800/1400] | CE Loss 0.4781
# EPOCH [1/10] | STEP [800/1400] | ADV Loss 0.5705
# EPOCH [1/10] | STEP [800/1400] | CON Loss 0.1897
# EPOCH [1/10] | STEP [800/1400] | VAT Loss 0.0281
# EPOCH [1/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [900/1400] | CE Loss 0.452
# EPOCH [1/10] | STEP [900/1400] | ADV Loss 0.5743
# EPOCH [1/10] | STEP [900/1400] | CON Loss 0.1721
# EPOCH [1/10] | STEP [900/1400] | VAT Loss 0.0262
# EPOCH [1/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [1000/1400] | CE Loss 0.4245
# EPOCH [1/10] | STEP [1000/1400] | ADV Loss 0.5535
# EPOCH [1/10] | STEP [1000/1400] | CON Loss 0.1647
# EPOCH [1/10] | STEP [1000/1400] | VAT Loss 0.0334
# EPOCH [1/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [1100/1400] | CE Loss 0.4764
# EPOCH [1/10] | STEP [1100/1400] | ADV Loss 0.5959
# EPOCH [1/10] | STEP [1100/1400] | CON Loss 0.1933
# EPOCH [1/10] | STEP [1100/1400] | VAT Loss 0.0254
# EPOCH [1/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [1200/1400] | CE Loss 0.4564
# EPOCH [1/10] | STEP [1200/1400] | ADV Loss 0.5865
# EPOCH [1/10] | STEP [1200/1400] | CON Loss 0.1825
# EPOCH [1/10] | STEP [1200/1400] | VAT Loss 0.0306
# EPOCH [1/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [1300/1400] | CE Loss 0.4389
# EPOCH [1/10] | STEP [1300/1400] | ADV Loss 0.571
# EPOCH [1/10] | STEP [1300/1400] | CON Loss 0.1659
# EPOCH [1/10] | STEP [1300/1400] | VAT Loss 0.0325
# EPOCH [1/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | STEP [1400/1400] | CE Loss 0.4212
# EPOCH [1/10] | STEP [1400/1400] | ADV Loss 0.5549
# EPOCH [1/10] | STEP [1400/1400] | CON Loss 0.1723
# EPOCH [1/10] | STEP [1400/1400] | VAT Loss 0.0251
# EPOCH [1/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [1/10] | Current F1-Macro 82.5
# EPOCH [1/10] | Best F1-Macro 82.5
# EPOCH [2/10] | STEP [100/1400] | CE Loss 0.3648
# EPOCH [2/10] | STEP [100/1400] | ADV Loss 0.5076
# EPOCH [2/10] | STEP [100/1400] | CON Loss 0.1434
# EPOCH [2/10] | STEP [100/1400] | VAT Loss 0.0238
# EPOCH [2/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [200/1400] | CE Loss 0.3375
# EPOCH [2/10] | STEP [200/1400] | ADV Loss 0.4968
# EPOCH [2/10] | STEP [200/1400] | CON Loss 0.1495
# EPOCH [2/10] | STEP [200/1400] | VAT Loss 0.0211
# EPOCH [2/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [300/1400] | CE Loss 0.3544
# EPOCH [2/10] | STEP [300/1400] | ADV Loss 0.5308
# EPOCH [2/10] | STEP [300/1400] | CON Loss 0.1411
# EPOCH [2/10] | STEP [300/1400] | VAT Loss 0.0247
# EPOCH [2/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [400/1400] | CE Loss 0.3684
# EPOCH [2/10] | STEP [400/1400] | ADV Loss 0.499
# EPOCH [2/10] | STEP [400/1400] | CON Loss 0.1509
# EPOCH [2/10] | STEP [400/1400] | VAT Loss 0.0233
# EPOCH [2/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [500/1400] | CE Loss 0.3721
# EPOCH [2/10] | STEP [500/1400] | ADV Loss 0.4941
# EPOCH [2/10] | STEP [500/1400] | CON Loss 0.1533
# EPOCH [2/10] | STEP [500/1400] | VAT Loss 0.0253
# EPOCH [2/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [600/1400] | CE Loss 0.3476
# EPOCH [2/10] | STEP [600/1400] | ADV Loss 0.4915
# EPOCH [2/10] | STEP [600/1400] | CON Loss 0.1401
# EPOCH [2/10] | STEP [600/1400] | VAT Loss 0.0226
# EPOCH [2/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [700/1400] | CE Loss 0.36
# EPOCH [2/10] | STEP [700/1400] | ADV Loss 0.5002
# EPOCH [2/10] | STEP [700/1400] | CON Loss 0.1581
# EPOCH [2/10] | STEP [700/1400] | VAT Loss 0.0213
# EPOCH [2/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [800/1400] | CE Loss 0.3286
# EPOCH [2/10] | STEP [800/1400] | ADV Loss 0.4957
# EPOCH [2/10] | STEP [800/1400] | CON Loss 0.137
# EPOCH [2/10] | STEP [800/1400] | VAT Loss 0.0189
# EPOCH [2/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [900/1400] | CE Loss 0.3334
# EPOCH [2/10] | STEP [900/1400] | ADV Loss 0.4698
# EPOCH [2/10] | STEP [900/1400] | CON Loss 0.1433
# EPOCH [2/10] | STEP [900/1400] | VAT Loss 0.0216
# EPOCH [2/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [1000/1400] | CE Loss 0.3459
# EPOCH [2/10] | STEP [1000/1400] | ADV Loss 0.4857
# EPOCH [2/10] | STEP [1000/1400] | CON Loss 0.1409
# EPOCH [2/10] | STEP [1000/1400] | VAT Loss 0.0263
# EPOCH [2/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [1100/1400] | CE Loss 0.3493
# EPOCH [2/10] | STEP [1100/1400] | ADV Loss 0.4816
# EPOCH [2/10] | STEP [1100/1400] | CON Loss 0.1455
# EPOCH [2/10] | STEP [1100/1400] | VAT Loss 0.0261
# EPOCH [2/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [1200/1400] | CE Loss 0.3475
# EPOCH [2/10] | STEP [1200/1400] | ADV Loss 0.5003
# EPOCH [2/10] | STEP [1200/1400] | CON Loss 0.1469
# EPOCH [2/10] | STEP [1200/1400] | VAT Loss 0.0312
# EPOCH [2/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [1300/1400] | CE Loss 0.3424
# EPOCH [2/10] | STEP [1300/1400] | ADV Loss 0.4742
# EPOCH [2/10] | STEP [1300/1400] | CON Loss 0.1472
# EPOCH [2/10] | STEP [1300/1400] | VAT Loss 0.0307
# EPOCH [2/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | STEP [1400/1400] | CE Loss 0.3441
# EPOCH [2/10] | STEP [1400/1400] | ADV Loss 0.4941
# EPOCH [2/10] | STEP [1400/1400] | CON Loss 0.1492
# EPOCH [2/10] | STEP [1400/1400] | VAT Loss 0.0233
# EPOCH [2/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [2/10] | Current F1-Macro 82.83
# EPOCH [2/10] | Best F1-Macro 82.83
# EPOCH [3/10] | STEP [100/1400] | CE Loss 0.2904
# EPOCH [3/10] | STEP [100/1400] | ADV Loss 0.4378
# EPOCH [3/10] | STEP [100/1400] | CON Loss 0.1211
# EPOCH [3/10] | STEP [100/1400] | VAT Loss 0.0311
# EPOCH [3/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [200/1400] | CE Loss 0.247
# EPOCH [3/10] | STEP [200/1400] | ADV Loss 0.4193
# EPOCH [3/10] | STEP [200/1400] | CON Loss 0.1047
# EPOCH [3/10] | STEP [200/1400] | VAT Loss 0.0294
# EPOCH [3/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [300/1400] | CE Loss 0.2687
# EPOCH [3/10] | STEP [300/1400] | ADV Loss 0.4187
# EPOCH [3/10] | STEP [300/1400] | CON Loss 0.1262
# EPOCH [3/10] | STEP [300/1400] | VAT Loss 0.0274
# EPOCH [3/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [400/1400] | CE Loss 0.218
# EPOCH [3/10] | STEP [400/1400] | ADV Loss 0.3643
# EPOCH [3/10] | STEP [400/1400] | CON Loss 0.0897
# EPOCH [3/10] | STEP [400/1400] | VAT Loss 0.0326
# EPOCH [3/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [500/1400] | CE Loss 0.2519
# EPOCH [3/10] | STEP [500/1400] | ADV Loss 0.3881
# EPOCH [3/10] | STEP [500/1400] | CON Loss 0.0987
# EPOCH [3/10] | STEP [500/1400] | VAT Loss 0.0238
# EPOCH [3/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [600/1400] | CE Loss 0.2593
# EPOCH [3/10] | STEP [600/1400] | ADV Loss 0.4127
# EPOCH [3/10] | STEP [600/1400] | CON Loss 0.1091
# EPOCH [3/10] | STEP [600/1400] | VAT Loss 0.0273
# EPOCH [3/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [700/1400] | CE Loss 0.2367
# EPOCH [3/10] | STEP [700/1400] | ADV Loss 0.3868
# EPOCH [3/10] | STEP [700/1400] | CON Loss 0.0921
# EPOCH [3/10] | STEP [700/1400] | VAT Loss 0.0274
# EPOCH [3/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [800/1400] | CE Loss 0.2408
# EPOCH [3/10] | STEP [800/1400] | ADV Loss 0.4061
# EPOCH [3/10] | STEP [800/1400] | CON Loss 0.1231
# EPOCH [3/10] | STEP [800/1400] | VAT Loss 0.0386
# EPOCH [3/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [900/1400] | CE Loss 0.2609
# EPOCH [3/10] | STEP [900/1400] | ADV Loss 0.4201
# EPOCH [3/10] | STEP [900/1400] | CON Loss 0.1155
# EPOCH [3/10] | STEP [900/1400] | VAT Loss 0.0246
# EPOCH [3/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [1000/1400] | CE Loss 0.2747
# EPOCH [3/10] | STEP [1000/1400] | ADV Loss 0.4025
# EPOCH [3/10] | STEP [1000/1400] | CON Loss 0.1149
# EPOCH [3/10] | STEP [1000/1400] | VAT Loss 0.0227
# EPOCH [3/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [1100/1400] | CE Loss 0.2619
# EPOCH [3/10] | STEP [1100/1400] | ADV Loss 0.4306
# EPOCH [3/10] | STEP [1100/1400] | CON Loss 0.1132
# EPOCH [3/10] | STEP [1100/1400] | VAT Loss 0.0284
# EPOCH [3/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [1200/1400] | CE Loss 0.2449
# EPOCH [3/10] | STEP [1200/1400] | ADV Loss 0.4022
# EPOCH [3/10] | STEP [1200/1400] | CON Loss 0.1075
# EPOCH [3/10] | STEP [1200/1400] | VAT Loss 0.0232
# EPOCH [3/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [1300/1400] | CE Loss 0.2684
# EPOCH [3/10] | STEP [1300/1400] | ADV Loss 0.4099
# EPOCH [3/10] | STEP [1300/1400] | CON Loss 0.1107
# EPOCH [3/10] | STEP [1300/1400] | VAT Loss 0.0224
# EPOCH [3/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | STEP [1400/1400] | CE Loss 0.2526
# EPOCH [3/10] | STEP [1400/1400] | ADV Loss 0.3822
# EPOCH [3/10] | STEP [1400/1400] | CON Loss 0.1004
# EPOCH [3/10] | STEP [1400/1400] | VAT Loss 0.021
# EPOCH [3/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [3/10] | Current F1-Macro 84.52
# EPOCH [3/10] | Best F1-Macro 84.52
# EPOCH [4/10] | STEP [100/1400] | CE Loss 0.1614
# EPOCH [4/10] | STEP [100/1400] | ADV Loss 0.3131
# EPOCH [4/10] | STEP [100/1400] | CON Loss 0.0645
# EPOCH [4/10] | STEP [100/1400] | VAT Loss 0.03
# EPOCH [4/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [200/1400] | CE Loss 0.1762
# EPOCH [4/10] | STEP [200/1400] | ADV Loss 0.3327
# EPOCH [4/10] | STEP [200/1400] | CON Loss 0.0677
# EPOCH [4/10] | STEP [200/1400] | VAT Loss 0.0312
# EPOCH [4/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [300/1400] | CE Loss 0.193
# EPOCH [4/10] | STEP [300/1400] | ADV Loss 0.3466
# EPOCH [4/10] | STEP [300/1400] | CON Loss 0.0688
# EPOCH [4/10] | STEP [300/1400] | VAT Loss 0.0296
# EPOCH [4/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [400/1400] | CE Loss 0.1836
# EPOCH [4/10] | STEP [400/1400] | ADV Loss 0.3291
# EPOCH [4/10] | STEP [400/1400] | CON Loss 0.0904
# EPOCH [4/10] | STEP [400/1400] | VAT Loss 0.026
# EPOCH [4/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [500/1400] | CE Loss 0.158
# EPOCH [4/10] | STEP [500/1400] | ADV Loss 0.313
# EPOCH [4/10] | STEP [500/1400] | CON Loss 0.0567
# EPOCH [4/10] | STEP [500/1400] | VAT Loss 0.0239
# EPOCH [4/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [600/1400] | CE Loss 0.1655
# EPOCH [4/10] | STEP [600/1400] | ADV Loss 0.3036
# EPOCH [4/10] | STEP [600/1400] | CON Loss 0.064
# EPOCH [4/10] | STEP [600/1400] | VAT Loss 0.0318
# EPOCH [4/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [700/1400] | CE Loss 0.1593
# EPOCH [4/10] | STEP [700/1400] | ADV Loss 0.3098
# EPOCH [4/10] | STEP [700/1400] | CON Loss 0.0703
# EPOCH [4/10] | STEP [700/1400] | VAT Loss 0.0286
# EPOCH [4/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [800/1400] | CE Loss 0.1722
# EPOCH [4/10] | STEP [800/1400] | ADV Loss 0.3248
# EPOCH [4/10] | STEP [800/1400] | CON Loss 0.0732
# EPOCH [4/10] | STEP [800/1400] | VAT Loss 0.0276
# EPOCH [4/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [900/1400] | CE Loss 0.1733
# EPOCH [4/10] | STEP [900/1400] | ADV Loss 0.3337
# EPOCH [4/10] | STEP [900/1400] | CON Loss 0.0668
# EPOCH [4/10] | STEP [900/1400] | VAT Loss 0.0239
# EPOCH [4/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [1000/1400] | CE Loss 0.1578
# EPOCH [4/10] | STEP [1000/1400] | ADV Loss 0.313
# EPOCH [4/10] | STEP [1000/1400] | CON Loss 0.0665
# EPOCH [4/10] | STEP [1000/1400] | VAT Loss 0.0282
# EPOCH [4/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [1100/1400] | CE Loss 0.1967
# EPOCH [4/10] | STEP [1100/1400] | ADV Loss 0.3506
# EPOCH [4/10] | STEP [1100/1400] | CON Loss 0.0822
# EPOCH [4/10] | STEP [1100/1400] | VAT Loss 0.0244
# EPOCH [4/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [1200/1400] | CE Loss 0.1949
# EPOCH [4/10] | STEP [1200/1400] | ADV Loss 0.3361
# EPOCH [4/10] | STEP [1200/1400] | CON Loss 0.0785
# EPOCH [4/10] | STEP [1200/1400] | VAT Loss 0.0212
# EPOCH [4/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [1300/1400] | CE Loss 0.1789
# EPOCH [4/10] | STEP [1300/1400] | ADV Loss 0.3238
# EPOCH [4/10] | STEP [1300/1400] | CON Loss 0.0667
# EPOCH [4/10] | STEP [1300/1400] | VAT Loss 0.0245
# EPOCH [4/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | STEP [1400/1400] | CE Loss 0.195
# EPOCH [4/10] | STEP [1400/1400] | ADV Loss 0.3401
# EPOCH [4/10] | STEP [1400/1400] | CON Loss 0.0832
# EPOCH [4/10] | STEP [1400/1400] | VAT Loss 0.0227
# EPOCH [4/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [4/10] | Current F1-Macro 85.71
# EPOCH [4/10] | Best F1-Macro 85.71
# EPOCH [5/10] | STEP [100/1400] | CE Loss 0.0947
# EPOCH [5/10] | STEP [100/1400] | ADV Loss 0.2268
# EPOCH [5/10] | STEP [100/1400] | CON Loss 0.031
# EPOCH [5/10] | STEP [100/1400] | VAT Loss 0.0229
# EPOCH [5/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [200/1400] | CE Loss 0.1224
# EPOCH [5/10] | STEP [200/1400] | ADV Loss 0.2733
# EPOCH [5/10] | STEP [200/1400] | CON Loss 0.0405
# EPOCH [5/10] | STEP [200/1400] | VAT Loss 0.0239
# EPOCH [5/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [300/1400] | CE Loss 0.0995
# EPOCH [5/10] | STEP [300/1400] | ADV Loss 0.233
# EPOCH [5/10] | STEP [300/1400] | CON Loss 0.0335
# EPOCH [5/10] | STEP [300/1400] | VAT Loss 0.029
# EPOCH [5/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [400/1400] | CE Loss 0.119
# EPOCH [5/10] | STEP [400/1400] | ADV Loss 0.2828
# EPOCH [5/10] | STEP [400/1400] | CON Loss 0.0379
# EPOCH [5/10] | STEP [400/1400] | VAT Loss 0.0232
# EPOCH [5/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [500/1400] | CE Loss 0.1215
# EPOCH [5/10] | STEP [500/1400] | ADV Loss 0.264
# EPOCH [5/10] | STEP [500/1400] | CON Loss 0.0415
# EPOCH [5/10] | STEP [500/1400] | VAT Loss 0.0239
# EPOCH [5/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [600/1400] | CE Loss 0.1195
# EPOCH [5/10] | STEP [600/1400] | ADV Loss 0.2611
# EPOCH [5/10] | STEP [600/1400] | CON Loss 0.045
# EPOCH [5/10] | STEP [600/1400] | VAT Loss 0.0234
# EPOCH [5/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [700/1400] | CE Loss 0.1119
# EPOCH [5/10] | STEP [700/1400] | ADV Loss 0.2446
# EPOCH [5/10] | STEP [700/1400] | CON Loss 0.0348
# EPOCH [5/10] | STEP [700/1400] | VAT Loss 0.0273
# EPOCH [5/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [800/1400] | CE Loss 0.1325
# EPOCH [5/10] | STEP [800/1400] | ADV Loss 0.3115
# EPOCH [5/10] | STEP [800/1400] | CON Loss 0.0411
# EPOCH [5/10] | STEP [800/1400] | VAT Loss 0.0269
# EPOCH [5/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [900/1400] | CE Loss 0.1161
# EPOCH [5/10] | STEP [900/1400] | ADV Loss 0.2583
# EPOCH [5/10] | STEP [900/1400] | CON Loss 0.0425
# EPOCH [5/10] | STEP [900/1400] | VAT Loss 0.0207
# EPOCH [5/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [1000/1400] | CE Loss 0.0882
# EPOCH [5/10] | STEP [1000/1400] | ADV Loss 0.2157
# EPOCH [5/10] | STEP [1000/1400] | CON Loss 0.0362
# EPOCH [5/10] | STEP [1000/1400] | VAT Loss 0.023
# EPOCH [5/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [1100/1400] | CE Loss 0.1261
# EPOCH [5/10] | STEP [1100/1400] | ADV Loss 0.2672
# EPOCH [5/10] | STEP [1100/1400] | CON Loss 0.0563
# EPOCH [5/10] | STEP [1100/1400] | VAT Loss 0.0269
# EPOCH [5/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [1200/1400] | CE Loss 0.1191
# EPOCH [5/10] | STEP [1200/1400] | ADV Loss 0.2756
# EPOCH [5/10] | STEP [1200/1400] | CON Loss 0.0439
# EPOCH [5/10] | STEP [1200/1400] | VAT Loss 0.0226
# EPOCH [5/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [1300/1400] | CE Loss 0.1148
# EPOCH [5/10] | STEP [1300/1400] | ADV Loss 0.286
# EPOCH [5/10] | STEP [1300/1400] | CON Loss 0.0429
# EPOCH [5/10] | STEP [1300/1400] | VAT Loss 0.0247
# EPOCH [5/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | STEP [1400/1400] | CE Loss 0.11
# EPOCH [5/10] | STEP [1400/1400] | ADV Loss 0.2567
# EPOCH [5/10] | STEP [1400/1400] | CON Loss 0.0363
# EPOCH [5/10] | STEP [1400/1400] | VAT Loss 0.0302
# EPOCH [5/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [5/10] | Current F1-Macro 85.32
# EPOCH [5/10] | Best F1-Macro 85.71
# EPOCH [6/10] | STEP [100/1400] | CE Loss 0.0751
# EPOCH [6/10] | STEP [100/1400] | ADV Loss 0.2234
# EPOCH [6/10] | STEP [100/1400] | CON Loss 0.0169
# EPOCH [6/10] | STEP [100/1400] | VAT Loss 0.0208
# EPOCH [6/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [200/1400] | CE Loss 0.0652
# EPOCH [6/10] | STEP [200/1400] | ADV Loss 0.1974
# EPOCH [6/10] | STEP [200/1400] | CON Loss 0.0209
# EPOCH [6/10] | STEP [200/1400] | VAT Loss 0.0202
# EPOCH [6/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [300/1400] | CE Loss 0.0724
# EPOCH [6/10] | STEP [300/1400] | ADV Loss 0.1958
# EPOCH [6/10] | STEP [300/1400] | CON Loss 0.0217
# EPOCH [6/10] | STEP [300/1400] | VAT Loss 0.0221
# EPOCH [6/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [400/1400] | CE Loss 0.0598
# EPOCH [6/10] | STEP [400/1400] | ADV Loss 0.2058
# EPOCH [6/10] | STEP [400/1400] | CON Loss 0.0089
# EPOCH [6/10] | STEP [400/1400] | VAT Loss 0.0265
# EPOCH [6/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [500/1400] | CE Loss 0.0893
# EPOCH [6/10] | STEP [500/1400] | ADV Loss 0.2327
# EPOCH [6/10] | STEP [500/1400] | CON Loss 0.0289
# EPOCH [6/10] | STEP [500/1400] | VAT Loss 0.027
# EPOCH [6/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [600/1400] | CE Loss 0.0864
# EPOCH [6/10] | STEP [600/1400] | ADV Loss 0.2087
# EPOCH [6/10] | STEP [600/1400] | CON Loss 0.0227
# EPOCH [6/10] | STEP [600/1400] | VAT Loss 0.0193
# EPOCH [6/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [700/1400] | CE Loss 0.0797
# EPOCH [6/10] | STEP [700/1400] | ADV Loss 0.2059
# EPOCH [6/10] | STEP [700/1400] | CON Loss 0.0238
# EPOCH [6/10] | STEP [700/1400] | VAT Loss 0.0168
# EPOCH [6/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [800/1400] | CE Loss 0.0747
# EPOCH [6/10] | STEP [800/1400] | ADV Loss 0.2203
# EPOCH [6/10] | STEP [800/1400] | CON Loss 0.0229
# EPOCH [6/10] | STEP [800/1400] | VAT Loss 0.0232
# EPOCH [6/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [900/1400] | CE Loss 0.0678
# EPOCH [6/10] | STEP [900/1400] | ADV Loss 0.1798
# EPOCH [6/10] | STEP [900/1400] | CON Loss 0.0216
# EPOCH [6/10] | STEP [900/1400] | VAT Loss 0.023
# EPOCH [6/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [1000/1400] | CE Loss 0.0883
# EPOCH [6/10] | STEP [1000/1400] | ADV Loss 0.2243
# EPOCH [6/10] | STEP [1000/1400] | CON Loss 0.0258
# EPOCH [6/10] | STEP [1000/1400] | VAT Loss 0.0279
# EPOCH [6/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [1100/1400] | CE Loss 0.0899
# EPOCH [6/10] | STEP [1100/1400] | ADV Loss 0.2096
# EPOCH [6/10] | STEP [1100/1400] | CON Loss 0.0252
# EPOCH [6/10] | STEP [1100/1400] | VAT Loss 0.02
# EPOCH [6/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [1200/1400] | CE Loss 0.0601
# EPOCH [6/10] | STEP [1200/1400] | ADV Loss 0.1707
# EPOCH [6/10] | STEP [1200/1400] | CON Loss 0.0117
# EPOCH [6/10] | STEP [1200/1400] | VAT Loss 0.0285
# EPOCH [6/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [1300/1400] | CE Loss 0.076
# EPOCH [6/10] | STEP [1300/1400] | ADV Loss 0.2097
# EPOCH [6/10] | STEP [1300/1400] | CON Loss 0.0193
# EPOCH [6/10] | STEP [1300/1400] | VAT Loss 0.023
# EPOCH [6/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | STEP [1400/1400] | CE Loss 0.0979
# EPOCH [6/10] | STEP [1400/1400] | ADV Loss 0.2326
# EPOCH [6/10] | STEP [1400/1400] | CON Loss 0.0303
# EPOCH [6/10] | STEP [1400/1400] | VAT Loss 0.027
# EPOCH [6/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [6/10] | Current F1-Macro 86.81
# EPOCH [6/10] | Best F1-Macro 86.81
# EPOCH [7/10] | STEP [100/1400] | CE Loss 0.0595
# EPOCH [7/10] | STEP [100/1400] | ADV Loss 0.1761
# EPOCH [7/10] | STEP [100/1400] | CON Loss 0.0092
# EPOCH [7/10] | STEP [100/1400] | VAT Loss 0.0135
# EPOCH [7/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [200/1400] | CE Loss 0.0673
# EPOCH [7/10] | STEP [200/1400] | ADV Loss 0.1778
# EPOCH [7/10] | STEP [200/1400] | CON Loss 0.0095
# EPOCH [7/10] | STEP [200/1400] | VAT Loss 0.0185
# EPOCH [7/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [300/1400] | CE Loss 0.0605
# EPOCH [7/10] | STEP [300/1400] | ADV Loss 0.1768
# EPOCH [7/10] | STEP [300/1400] | CON Loss 0.0109
# EPOCH [7/10] | STEP [300/1400] | VAT Loss 0.0273
# EPOCH [7/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [400/1400] | CE Loss 0.0595
# EPOCH [7/10] | STEP [400/1400] | ADV Loss 0.2019
# EPOCH [7/10] | STEP [400/1400] | CON Loss 0.0184
# EPOCH [7/10] | STEP [400/1400] | VAT Loss 0.0193
# EPOCH [7/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [500/1400] | CE Loss 0.0663
# EPOCH [7/10] | STEP [500/1400] | ADV Loss 0.1889
# EPOCH [7/10] | STEP [500/1400] | CON Loss 0.0188
# EPOCH [7/10] | STEP [500/1400] | VAT Loss 0.018
# EPOCH [7/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [600/1400] | CE Loss 0.0505
# EPOCH [7/10] | STEP [600/1400] | ADV Loss 0.1732
# EPOCH [7/10] | STEP [600/1400] | CON Loss 0.0136
# EPOCH [7/10] | STEP [600/1400] | VAT Loss 0.0249
# EPOCH [7/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [700/1400] | CE Loss 0.0481
# EPOCH [7/10] | STEP [700/1400] | ADV Loss 0.1743
# EPOCH [7/10] | STEP [700/1400] | CON Loss 0.0082
# EPOCH [7/10] | STEP [700/1400] | VAT Loss 0.0183
# EPOCH [7/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [800/1400] | CE Loss 0.0613
# EPOCH [7/10] | STEP [800/1400] | ADV Loss 0.1901
# EPOCH [7/10] | STEP [800/1400] | CON Loss 0.0147
# EPOCH [7/10] | STEP [800/1400] | VAT Loss 0.0261
# EPOCH [7/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [900/1400] | CE Loss 0.0527
# EPOCH [7/10] | STEP [900/1400] | ADV Loss 0.1627
# EPOCH [7/10] | STEP [900/1400] | CON Loss 0.0116
# EPOCH [7/10] | STEP [900/1400] | VAT Loss 0.0241
# EPOCH [7/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [1000/1400] | CE Loss 0.0581
# EPOCH [7/10] | STEP [1000/1400] | ADV Loss 0.1574
# EPOCH [7/10] | STEP [1000/1400] | CON Loss 0.0122
# EPOCH [7/10] | STEP [1000/1400] | VAT Loss 0.0195
# EPOCH [7/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [1100/1400] | CE Loss 0.0449
# EPOCH [7/10] | STEP [1100/1400] | ADV Loss 0.1803
# EPOCH [7/10] | STEP [1100/1400] | CON Loss 0.0163
# EPOCH [7/10] | STEP [1100/1400] | VAT Loss 0.0237
# EPOCH [7/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [1200/1400] | CE Loss 0.0326
# EPOCH [7/10] | STEP [1200/1400] | ADV Loss 0.1315
# EPOCH [7/10] | STEP [1200/1400] | CON Loss 0.003
# EPOCH [7/10] | STEP [1200/1400] | VAT Loss 0.0187
# EPOCH [7/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [1300/1400] | CE Loss 0.0653
# EPOCH [7/10] | STEP [1300/1400] | ADV Loss 0.2007
# EPOCH [7/10] | STEP [1300/1400] | CON Loss 0.017
# EPOCH [7/10] | STEP [1300/1400] | VAT Loss 0.0184
# EPOCH [7/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | STEP [1400/1400] | CE Loss 0.0456
# EPOCH [7/10] | STEP [1400/1400] | ADV Loss 0.1611
# EPOCH [7/10] | STEP [1400/1400] | CON Loss 0.0107
# EPOCH [7/10] | STEP [1400/1400] | VAT Loss 0.0165
# EPOCH [7/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [7/10] | Current F1-Macro 86.65
# EPOCH [7/10] | Best F1-Macro 86.81
# EPOCH [8/10] | STEP [100/1400] | CE Loss 0.0407
# EPOCH [8/10] | STEP [100/1400] | ADV Loss 0.1409
# EPOCH [8/10] | STEP [100/1400] | CON Loss 0.0067
# EPOCH [8/10] | STEP [100/1400] | VAT Loss 0.0173
# EPOCH [8/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [200/1400] | CE Loss 0.0379
# EPOCH [8/10] | STEP [200/1400] | ADV Loss 0.1408
# EPOCH [8/10] | STEP [200/1400] | CON Loss 0.0071
# EPOCH [8/10] | STEP [200/1400] | VAT Loss 0.0148
# EPOCH [8/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [300/1400] | CE Loss 0.0363
# EPOCH [8/10] | STEP [300/1400] | ADV Loss 0.1245
# EPOCH [8/10] | STEP [300/1400] | CON Loss 0.0039
# EPOCH [8/10] | STEP [300/1400] | VAT Loss 0.0203
# EPOCH [8/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [400/1400] | CE Loss 0.0276
# EPOCH [8/10] | STEP [400/1400] | ADV Loss 0.1296
# EPOCH [8/10] | STEP [400/1400] | CON Loss 0.0042
# EPOCH [8/10] | STEP [400/1400] | VAT Loss 0.0198
# EPOCH [8/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [500/1400] | CE Loss 0.0279
# EPOCH [8/10] | STEP [500/1400] | ADV Loss 0.1275
# EPOCH [8/10] | STEP [500/1400] | CON Loss 0.0035
# EPOCH [8/10] | STEP [500/1400] | VAT Loss 0.017
# EPOCH [8/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [600/1400] | CE Loss 0.0406
# EPOCH [8/10] | STEP [600/1400] | ADV Loss 0.1399
# EPOCH [8/10] | STEP [600/1400] | CON Loss 0.0134
# EPOCH [8/10] | STEP [600/1400] | VAT Loss 0.0158
# EPOCH [8/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [700/1400] | CE Loss 0.0448
# EPOCH [8/10] | STEP [700/1400] | ADV Loss 0.1797
# EPOCH [8/10] | STEP [700/1400] | CON Loss 0.0128
# EPOCH [8/10] | STEP [700/1400] | VAT Loss 0.0168
# EPOCH [8/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [800/1400] | CE Loss 0.0336
# EPOCH [8/10] | STEP [800/1400] | ADV Loss 0.1393
# EPOCH [8/10] | STEP [800/1400] | CON Loss 0.0046
# EPOCH [8/10] | STEP [800/1400] | VAT Loss 0.017
# EPOCH [8/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [900/1400] | CE Loss 0.0422
# EPOCH [8/10] | STEP [900/1400] | ADV Loss 0.1487
# EPOCH [8/10] | STEP [900/1400] | CON Loss 0.0143
# EPOCH [8/10] | STEP [900/1400] | VAT Loss 0.0183
# EPOCH [8/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [1000/1400] | CE Loss 0.0513
# EPOCH [8/10] | STEP [1000/1400] | ADV Loss 0.1842
# EPOCH [8/10] | STEP [1000/1400] | CON Loss 0.0134
# EPOCH [8/10] | STEP [1000/1400] | VAT Loss 0.0171
# EPOCH [8/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [1100/1400] | CE Loss 0.0375
# EPOCH [8/10] | STEP [1100/1400] | ADV Loss 0.1389
# EPOCH [8/10] | STEP [1100/1400] | CON Loss 0.0079
# EPOCH [8/10] | STEP [1100/1400] | VAT Loss 0.0188
# EPOCH [8/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [1200/1400] | CE Loss 0.0416
# EPOCH [8/10] | STEP [1200/1400] | ADV Loss 0.149
# EPOCH [8/10] | STEP [1200/1400] | CON Loss 0.0096
# EPOCH [8/10] | STEP [1200/1400] | VAT Loss 0.0166
# EPOCH [8/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [1300/1400] | CE Loss 0.0321
# EPOCH [8/10] | STEP [1300/1400] | ADV Loss 0.1249
# EPOCH [8/10] | STEP [1300/1400] | CON Loss 0.0041
# EPOCH [8/10] | STEP [1300/1400] | VAT Loss 0.0157
# EPOCH [8/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | STEP [1400/1400] | CE Loss 0.0317
# EPOCH [8/10] | STEP [1400/1400] | ADV Loss 0.1362
# EPOCH [8/10] | STEP [1400/1400] | CON Loss 0.01
# EPOCH [8/10] | STEP [1400/1400] | VAT Loss 0.0192
# EPOCH [8/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [8/10] | Current F1-Macro 86.69
# EPOCH [8/10] | Best F1-Macro 86.81
# EPOCH [9/10] | STEP [100/1400] | CE Loss 0.0276
# EPOCH [9/10] | STEP [100/1400] | ADV Loss 0.1223
# EPOCH [9/10] | STEP [100/1400] | CON Loss 0.0041
# EPOCH [9/10] | STEP [100/1400] | VAT Loss 0.0137
# EPOCH [9/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [200/1400] | CE Loss 0.0279
# EPOCH [9/10] | STEP [200/1400] | ADV Loss 0.1566
# EPOCH [9/10] | STEP [200/1400] | CON Loss 0.0044
# EPOCH [9/10] | STEP [200/1400] | VAT Loss 0.0213
# EPOCH [9/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [300/1400] | CE Loss 0.0303
# EPOCH [9/10] | STEP [300/1400] | ADV Loss 0.1229
# EPOCH [9/10] | STEP [300/1400] | CON Loss 0.0027
# EPOCH [9/10] | STEP [300/1400] | VAT Loss 0.0133
# EPOCH [9/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [400/1400] | CE Loss 0.0265
# EPOCH [9/10] | STEP [400/1400] | ADV Loss 0.1198
# EPOCH [9/10] | STEP [400/1400] | CON Loss 0.0052
# EPOCH [9/10] | STEP [400/1400] | VAT Loss 0.0145
# EPOCH [9/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [500/1400] | CE Loss 0.0362
# EPOCH [9/10] | STEP [500/1400] | ADV Loss 0.1358
# EPOCH [9/10] | STEP [500/1400] | CON Loss 0.0127
# EPOCH [9/10] | STEP [500/1400] | VAT Loss 0.0143
# EPOCH [9/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [600/1400] | CE Loss 0.0308
# EPOCH [9/10] | STEP [600/1400] | ADV Loss 0.1285
# EPOCH [9/10] | STEP [600/1400] | CON Loss 0.0057
# EPOCH [9/10] | STEP [600/1400] | VAT Loss 0.0144
# EPOCH [9/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [700/1400] | CE Loss 0.0331
# EPOCH [9/10] | STEP [700/1400] | ADV Loss 0.1357
# EPOCH [9/10] | STEP [700/1400] | CON Loss 0.0059
# EPOCH [9/10] | STEP [700/1400] | VAT Loss 0.0155
# EPOCH [9/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [800/1400] | CE Loss 0.0294
# EPOCH [9/10] | STEP [800/1400] | ADV Loss 0.1203
# EPOCH [9/10] | STEP [800/1400] | CON Loss 0.0044
# EPOCH [9/10] | STEP [800/1400] | VAT Loss 0.0151
# EPOCH [9/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [900/1400] | CE Loss 0.0273
# EPOCH [9/10] | STEP [900/1400] | ADV Loss 0.1227
# EPOCH [9/10] | STEP [900/1400] | CON Loss 0.0058
# EPOCH [9/10] | STEP [900/1400] | VAT Loss 0.0106
# EPOCH [9/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [1000/1400] | CE Loss 0.0244
# EPOCH [9/10] | STEP [1000/1400] | ADV Loss 0.1173
# EPOCH [9/10] | STEP [1000/1400] | CON Loss 0.0036
# EPOCH [9/10] | STEP [1000/1400] | VAT Loss 0.0179
# EPOCH [9/10] | STEP [1000/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [1100/1400] | CE Loss 0.0273
# EPOCH [9/10] | STEP [1100/1400] | ADV Loss 0.1135
# EPOCH [9/10] | STEP [1100/1400] | CON Loss 0.0059
# EPOCH [9/10] | STEP [1100/1400] | VAT Loss 0.0172
# EPOCH [9/10] | STEP [1100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [1200/1400] | CE Loss 0.0261
# EPOCH [9/10] | STEP [1200/1400] | ADV Loss 0.1415
# EPOCH [9/10] | STEP [1200/1400] | CON Loss 0.0051
# EPOCH [9/10] | STEP [1200/1400] | VAT Loss 0.0124
# EPOCH [9/10] | STEP [1200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [1300/1400] | CE Loss 0.0383
# EPOCH [9/10] | STEP [1300/1400] | ADV Loss 0.1422
# EPOCH [9/10] | STEP [1300/1400] | CON Loss 0.007
# EPOCH [9/10] | STEP [1300/1400] | VAT Loss 0.0221
# EPOCH [9/10] | STEP [1300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | STEP [1400/1400] | CE Loss 0.0343
# EPOCH [9/10] | STEP [1400/1400] | ADV Loss 0.1333
# EPOCH [9/10] | STEP [1400/1400] | CON Loss 0.0076
# EPOCH [9/10] | STEP [1400/1400] | VAT Loss 0.0154
# EPOCH [9/10] | STEP [1400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [9/10] | Current F1-Macro 86.55
# EPOCH [9/10] | Best F1-Macro 86.81
# EPOCH [10/10] | STEP [100/1400] | CE Loss 0.0246
# EPOCH [10/10] | STEP [100/1400] | ADV Loss 0.1196
# EPOCH [10/10] | STEP [100/1400] | CON Loss 0.0051
# EPOCH [10/10] | STEP [100/1400] | VAT Loss 0.0188
# EPOCH [10/10] | STEP [100/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [10/10] | STEP [200/1400] | CE Loss 0.0248
# EPOCH [10/10] | STEP [200/1400] | ADV Loss 0.125
# EPOCH [10/10] | STEP [200/1400] | CON Loss 0.0036
# EPOCH [10/10] | STEP [200/1400] | VAT Loss 0.0126
# EPOCH [10/10] | STEP [200/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [10/10] | STEP [300/1400] | CE Loss 0.0369
# EPOCH [10/10] | STEP [300/1400] | ADV Loss 0.1372
# EPOCH [10/10] | STEP [300/1400] | CON Loss 0.0043
# EPOCH [10/10] | STEP [300/1400] | VAT Loss 0.0175
# EPOCH [10/10] | STEP [300/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [10/10] | STEP [400/1400] | CE Loss 0.0318
# EPOCH [10/10] | STEP [400/1400] | ADV Loss 0.1326
# EPOCH [10/10] | STEP [400/1400] | CON Loss 0.0066
# EPOCH [10/10] | STEP [400/1400] | VAT Loss 0.0166
# EPOCH [10/10] | STEP [400/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [10/10] | STEP [500/1400] | CE Loss 0.0327
# EPOCH [10/10] | STEP [500/1400] | ADV Loss 0.1362
# EPOCH [10/10] | STEP [500/1400] | CON Loss 0.0043
# EPOCH [10/10] | STEP [500/1400] | VAT Loss 0.0195
# EPOCH [10/10] | STEP [500/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [10/10] | STEP [600/1400] | CE Loss 0.0285
# EPOCH [10/10] | STEP [600/1400] | ADV Loss 0.1141
# EPOCH [10/10] | STEP [600/1400] | CON Loss 0.005
# EPOCH [10/10] | STEP [600/1400] | VAT Loss 0.014
# EPOCH [10/10] | STEP [600/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [10/10] | STEP [700/1400] | CE Loss 0.0248
# EPOCH [10/10] | STEP [700/1400] | ADV Loss 0.1144
# EPOCH [10/10] | STEP [700/1400] | CON Loss 0.0026
# EPOCH [10/10] | STEP [700/1400] | VAT Loss 0.0131
# EPOCH [10/10] | STEP [700/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [10/10] | STEP [800/1400] | CE Loss 0.0284
# EPOCH [10/10] | STEP [800/1400] | ADV Loss 0.1338
# EPOCH [10/10] | STEP [800/1400] | CON Loss 0.0097
# EPOCH [10/10] | STEP [800/1400] | VAT Loss 0.0152
# EPOCH [10/10] | STEP [800/1400] | UL Loss 0.0
# ------------------------------------------------
# EPOCH [10/10] | STEP [900/1400] | CE Loss 0.0226
# EPOCH [10/10] | STEP [900/1400] | ADV Loss 0.1155
# EPOCH [10/10] | STEP [900/1400] | CON Loss 0.0064
# EPOCH [10/10] | STEP [900/1400] | VAT Loss 0.0126
# EPOCH [10/10] | STEP [900/1400] | UL Loss 0.0
# ------------------------------------------------
#
# ^C
